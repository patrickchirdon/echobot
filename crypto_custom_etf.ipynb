# %% [markdown]
# <a href="https://colab.research.google.com/github/patrickchirdon/echobot/blob/main/crypto_custom_etf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import math
from decimal import Decimal
# !pip install alpaca-trade-api
# !pip install lumibot
import pandas as pd
from credentials import ALPACA_CONFIG, KUCOIN_CONFIG
from lumibot.backtesting import PandasDataBacktesting
from lumibot.brokers import Alpaca
from lumibot.brokers.ccxt import Ccxt
from lumibot.entities import Asset, Data, TradingFee
from lumibot.strategies.strategy import Strategy
from lumibot.traders import Trader

"""
Strategy Description
This strategy will buy a few of the top cryptocurrencies and rebalance the portfolio often.
"""


class CustomETF(Strategy):
    # =====Overloading lifecycle methods=============

    parameters = {
        "portfolio": [
            {
                "symbol": Asset(symbol="BTC", asset_type="crypto"),
                "weight": 0.32,
            },
            {
                "symbol": Asset(symbol="ETH", asset_type="crypto"),
                "weight": 0.32,
            },
            {
                "symbol": Asset(symbol="LTC", asset_type="crypto"),
                "weight": 0.32,
            },
        ],
    }

    def initialize(self):
        self.sleeptime = "10D"
        self.set_market("24/7")  # Need to do for crypto!

    def on_trading_iteration(self):
        self.rebalance_portfolio()

    # =============Helper methods===================

    def rebalance_portfolio(self):
        """Rebalance the portfolio and create orders"""
        orders = []
        for asset in self.parameters["portfolio"]:
            # Get all of our variables from portfolio
            asset_to_trade = asset.get("symbol")
            weight = asset.get("weight")
            quote = self.quote_asset
            symbol = asset_to_trade.symbol
            dt = self.get_datetime()
            last_price = self.get_last_price(asset_to_trade, quote=quote)

            if last_price is None:
                self.log_message(
                    f"Couldn't get a price for {symbol} self.get_last_price() returned None"
                )
                continue

            self.log_message(
                f"Last price for {symbol} is {last_price:,f}, and our weight is {weight}. Current portfolio value is {self.portfolio_value}"
            )

            # Get how many shares we already own
            # (including orders that haven't been executed yet)
            quantity = Decimal(str(self.get_asset_potential_total(asset_to_trade)))

            # Calculate how many shares we need to buy or sell
            shares_value = self.portfolio_value * weight
            new_quantity = Decimal(str(shares_value / last_price))

            quantity_difference = new_quantity - quantity
            self.log_message(
                f"Currently own {quantity} shares of {symbol} but need {new_quantity}, so the difference is {quantity_difference}"
            )

            # If quantity is positive then buy, if it's negative then sell
            side = ""
            if quantity_difference > 0:
                side = "buy"
            elif quantity_difference < 0:
                side = "sell"

            # Execute the
            # order if necessary
            if side:
                qty = abs(quantity_difference)

                # Trim to 2 decimal places because the API only accepts
                # 2 decimal places for some assets. This could be done better
                # on an asset by asset basis. e.g. for BTC, we want to use 4
                # decimal places at Alpaca, or a 0.0001 increment. See other coins
                # at Alpaca here: https://alpaca.markets/docs/trading/crypto-trading/
                qty_trimmed = qty.quantize(Decimal("0.001"), rounding="ROUND_DOWN")

                if qty_trimmed > 0:
                    order = self.create_order(
                        asset_to_trade,
                        qty_trimmed,
                        side,
                        quote=quote,
                    )
                    orders.append(order)

        if len(orders) == 0:
            self.log_message("No orders to execute")

        # Execute sell orders first so that we have the cash to buy the new shares
        for order in orders:
            if order.side == "sell":
                self.submit_order(order)

        # Sleep for 5 seconds to make sure the sell orders are filled
        self.sleep(5)

        # Execute buy orders
        for order in orders:
            if order.side == "buy":
                self.submit_order(order)


if __name__ == "__main__":
    # True if you want to trade live or False if you want to backtest
    is_live = True

    if is_live:
        ####
        # Live Trading
        ####

        trader = Trader()

        # broker = Ccxt(KUCOIN_CONFIG)
        # quote_asset = Asset(symbol="USDT", asset_type="crypto")

        broker = Alpaca(ALPACA_CONFIG)
        quote_asset = Asset(symbol="USD", asset_type="forex")

        strategy = CustomETF(broker, quote_asset=quote_asset)

        trader.add_strategy(strategy)
        strategies = trader.run_all()

    else:
        ####
        # Backtesting
        ####

        # Choose your initial conditions
        backtesting_start = datetime.datetime(2021, 1, 15)
        backtesting_end = datetime.datetime(2021, 12, 31)
        benchmark_asset = "BTC-USD"

        # Load all the data
        symbols = ["BTC", "ETH", "LTC"]
        pandas_data = {}
        for symbol in symbols:
            # Get the path for the data
            filepath = f"Day 11/code/data/Gemini_{symbol}USD_2021_1min.csv"

            # Skip the first row since it's not the data we want
            df = pd.read_csv(filepath, skiprows=1)

            # Convert the date column to a datetime object that is timezone aware
            df["Date"] = pd.to_datetime(df["Date"])
            df = df.set_index("Date")
            df.index = df.index.tz_localize("UTC")

            # Create a Data object from the Pandas DataFrame and add it to the
            # pandas_data dictionary
            base_asset = Asset(symbol=symbol, asset_type="crypto")
            quote_asset = Asset(symbol="USD", asset_type="forex")
            pandas_data[(base_asset, quote_asset)] = Data(
                base_asset, df, timestep="minute", quote=quote_asset
            )

        trading_fee = TradingFee(percent_fee=0.001)  # 0.1% fee
        # Run the backtest
        CustomETF.backtest(
            PandasDataBacktesting,
            backtesting_start,
            backtesting_end,
            pandas_data=pandas_data,
            benchmark_asset=benchmark_asset,
            quote_asset=Asset(symbol="USD", asset_type="forex"),
            buy_trading_fees=[trading_fee],
            sell_trading_fees=[trading_fee],
        )
# Out:
# ERROR: Operation cancelled by user
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lumibot in /usr/local/lib/python3.9/dist-packages (2.5.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from lumibot) (2.2.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from lumibot) (5.13.1)
# Requirement already satisfied: marshmallow-sqlalchemy in /usr/local/lib/python3.9/dist-packages (from lumibot) (0.29.0)
# Requirement already satisfied: flask-security in /usr/local/lib/python3.9/dist-packages (from lumibot) (3.0.0)
# Requirement already satisfied: quandl in /usr/local/lib/python3.9/dist-packages (from lumibot) (3.7.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.9/dist-packages (from lumibot) (7.2.2)
# Requirement already satisfied: email-validator in /usr/local/lib/python3.9/dist-packages (from lumibot) (2.0.0.post2)
# Requirement already satisfied: flask-socketio in /usr/local/lib/python3.9/dist-packages (from lumibot) (5.3.3)
# Requirement already satisfied: ibapi==9.81.1.post1 in /usr/local/lib/python3.9/dist-packages (from lumibot) (9.81.1.post1)
# Requirement already satisfied: flask-marshmallow in /usr/local/lib/python3.9/dist-packages (from lumibot) (0.15.0)
# Requirement already satisfied: pandas-datareader in /usr/local/lib/python3.9/dist-packages (from lumibot) (0.10.0)
# Requirement already satisfied: pandas-market-calendars>=4.1.2 in /usr/local/lib/python3.9/dist-packages (from lumibot) (4.1.4)
# Requirement already satisfied: yfinance==0.2.10 in /usr/local/lib/python3.9/dist-packages (from lumibot) (0.2.10)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.9/dist-packages (from lumibot) (3.0.1)
# Requirement already satisfied: alpaca-trade-api==2.3.0 in /usr/local/lib/python3.9/dist-packages (from lumibot) (2.3.0)
# Requirement already satisfied: alpha-vantage in /usr/local/lib/python3.9/dist-packages (from lumibot) (2.3.1)
# Requirement already satisfied: flask-sqlalchemy in /usr/local/lib/python3.9/dist-packages (from lumibot) (3.0.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from lumibot) (1.10.7)
# Requirement already satisfied: bcrypt in /usr/local/lib/python3.9/dist-packages (from lumibot) (4.0.1)
# Requirement already satisfied: quantstats==0.0.59 in /usr/local/lib/python3.9/dist-packages (from lumibot) (0.0.59)
# Requirement already satisfied: matplotlib>=3.3.3 in /usr/local/lib/python3.9/dist-packages (from lumibot) (3.7.1)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from lumibot) (1.5.3)
# Requirement already satisfied: ccxt==3.0.61 in /usr/local/lib/python3.9/dist-packages (from lumibot) (3.0.61)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from lumibot) (1.10.1)
# Requirement already satisfied: deprecation==2.1.0 in /usr/local/lib/python3.9/dist-packages (from alpaca-trade-api==2.3.0->lumibot) (2.1.0)
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.9/dist-packages (from alpaca-trade-api==2.3.0->lumibot) (6.0)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.9/dist-packages (from alpaca-trade-api==2.3.0->lumibot) (1.22.4)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.9/dist-packages (from alpaca-trade-api==2.3.0->lumibot) (1.5.1)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.9/dist-packages (from alpaca-trade-api==2.3.0->lumibot) (2.27.1)
# Requirement already satisfied: msgpack==1.0.3 in /usr/local/lib/python3.9/dist-packages (from alpaca-trade-api==2.3.0->lumibot) (1.0.3)
# Requirement already satisfied: websockets<11,>=9.0 in /usr/local/lib/python3.9/dist-packages (from alpaca-trade-api==2.3.0->lumibot) (10.4)
# Requirement already satisfied: aiohttp==3.8.1 in /usr/local/lib/python3.9/dist-packages (from alpaca-trade-api==2.3.0->lumibot) (3.8.1)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.9/dist-packages (from alpaca-trade-api==2.3.0->lumibot) (1.26.15)
# Requirement already satisfied: aiodns>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from ccxt==3.0.61->lumibot) (3.0.0)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.9/dist-packages (from ccxt==3.0.61->lumibot) (40.0.2)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.9/dist-packages (from ccxt==3.0.61->lumibot) (2022.12.7)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.9/dist-packages (from ccxt==3.0.61->lumibot) (67.6.1)
# Requirement already satisfied: yarl>=1.7.2 in /usr/local/lib/python3.9/dist-packages (from ccxt==3.0.61->lumibot) (1.9.1)
# Requirement already satisfied: tabulate>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from quantstats==0.0.59->lumibot) (0.8.10)
# Requirement already satisfied: python-dateutil>=2.0 in /usr/local/lib/python3.9/dist-packages (from quantstats==0.0.59->lumibot) (2.8.2)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from quantstats==0.0.59->lumibot) (0.12.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.9/dist-packages (from yfinance==0.2.10->lumibot) (2.3.7)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.9/dist-packages (from yfinance==0.2.10->lumibot) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.9/dist-packages (from yfinance==0.2.10->lumibot) (4.9.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.9/dist-packages (from yfinance==0.2.10->lumibot) (1.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.9/dist-packages (from yfinance==0.2.10->lumibot) (4.11.2)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.9/dist-packages (from yfinance==0.2.10->lumibot) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.9/dist-packages (from yfinance==0.2.10->lumibot) (2022.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.1->alpaca-trade-api==2.3.0->lumibot) (23.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.1->alpaca-trade-api==2.3.0->lumibot) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.1->alpaca-trade-api==2.3.0->lumibot) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.1->alpaca-trade-api==2.3.0->lumibot) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.1->alpaca-trade-api==2.3.0->lumibot) (6.0.4)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.1->alpaca-trade-api==2.3.0->lumibot) (2.0.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from deprecation==2.1.0->alpaca-trade-api==2.3.0->lumibot) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->lumibot) (4.39.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->lumibot) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->lumibot) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->lumibot) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->lumibot) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->lumibot) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->lumibot) (1.4.4)
# Requirement already satisfied: exchange-calendars>=3.3 in /usr/local/lib/python3.9/dist-packages (from pandas-market-calendars>=4.1.2->lumibot) (4.2.6)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from email-validator->lumibot) (2.3.0)
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from email-validator->lumibot) (3.4)
# Requirement already satisfied: Flask in /usr/local/lib/python3.9/dist-packages (from flask-marshmallow->lumibot) (2.2.3)
# Requirement already satisfied: marshmallow>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from flask-marshmallow->lumibot) (3.19.0)
# Requirement already satisfied: passlib>=1.7 in /usr/local/lib/python3.9/dist-packages (from flask-security->lumibot) (1.7.4)
# Requirement already satisfied: itsdangerous>=0.21 in /usr/local/lib/python3.9/dist-packages (from flask-security->lumibot) (2.1.2)
# Requirement already satisfied: Flask-WTF>=0.13.1 in /usr/local/lib/python3.9/dist-packages (from flask-security->lumibot) (1.1.1)
# Requirement already satisfied: Flask-Login>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from flask-security->lumibot) (0.6.2)
# Requirement already satisfied: Flask-Principal>=0.3.3 in /usr/local/lib/python3.9/dist-packages (from flask-security->lumibot) (0.4.0)
# Requirement already satisfied: Flask-Mail>=0.7.3 in /usr/local/lib/python3.9/dist-packages (from flask-security->lumibot) (0.9.1)
# Requirement already satisfied: Flask-BabelEx>=0.9.3 in /usr/local/lib/python3.9/dist-packages (from flask-security->lumibot) (0.9.4)
# Requirement already satisfied: python-socketio>=5.0.2 in /usr/local/lib/python3.9/dist-packages (from flask-socketio->lumibot) (5.8.0)
# Requirement already satisfied: SQLAlchemy>=1.4.18 in /usr/local/lib/python3.9/dist-packages (from flask-sqlalchemy->lumibot) (2.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->lumibot) (8.2.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic->lumibot) (4.5.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.9/dist-packages (from pytest->lumibot) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /usr/local/lib/python3.9/dist-packages (from pytest->lumibot) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pytest->lumibot) (2.0.1)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.9/dist-packages (from pytest->lumibot) (2.0.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from quandl->lumibot) (9.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from quandl->lumibot) (1.16.0)
# Requirement already satisfied: inflection>=0.3.1 in /usr/local/lib/python3.9/dist-packages (from quandl->lumibot) (0.5.1)
# Requirement already satisfied: pycares>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from aiodns>=1.1.1->ccxt==3.0.61->lumibot) (4.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.10->lumibot) (2.4.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=2.6.1->ccxt==3.0.61->lumibot) (1.15.1)
# Requirement already satisfied: pyluach in /usr/local/lib/python3.9/dist-packages (from exchange-calendars>=3.3->pandas-market-calendars>=4.1.2->lumibot) (2.2.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from exchange-calendars>=3.3->pandas-market-calendars>=4.1.2->lumibot) (0.12.0)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.9/dist-packages (from exchange-calendars>=3.3->pandas-market-calendars>=4.1.2->lumibot) (0.3.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from Flask->flask-marshmallow->lumibot) (2.2.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from Flask->flask-marshmallow->lumibot) (6.4.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.9/dist-packages (from Flask->flask-marshmallow->lumibot) (8.1.3)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.9/dist-packages (from Flask->flask-marshmallow->lumibot) (3.1.2)
# Requirement already satisfied: Babel>=1.0 in /usr/local/lib/python3.9/dist-packages (from Flask-BabelEx>=0.9.3->flask-security->lumibot) (2.12.1)
# Requirement already satisfied: speaklater>=1.2 in /usr/local/lib/python3.9/dist-packages (from Flask-BabelEx>=0.9.3->flask-security->lumibot) (1.3)
# Requirement already satisfied: blinker in /usr/local/lib/python3.9/dist-packages (from Flask-Mail>=0.7.3->flask-security->lumibot) (1.6.2)
# Requirement already satisfied: WTForms in /usr/local/lib/python3.9/dist-packages (from Flask-WTF>=0.13.1->flask-security->lumibot) (3.0.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance==0.2.10->lumibot) (0.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.3->lumibot) (3.15.0)
# Requirement already satisfied: python-engineio>=4.3.0 in /usr/local/lib/python3.9/dist-packages (from python-socketio>=5.0.2->flask-socketio->lumibot) (4.4.1)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/lib/python3.9/dist-packages (from python-socketio>=5.0.2->flask-socketio->lumibot) (0.22.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from SQLAlchemy>=1.4.18->flask-sqlalchemy->lumibot) (2.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt==3.0.61->lumibot) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=3.0->Flask->flask-marshmallow->lumibot) (2.1.2)
# ERROR: Operation cancelled by user
# 2023-04-21 22:07:19,997: root: INFO: Waiting for the socket stream connection to be established,
#                 method _stream_established must be called
# 2023-04-21 22:07:20,013: alpaca_trade_api.stream: INFO: started trading stream
# 2023-04-21 22:07:20,015: alpaca_trade_api.stream: INFO: starting trading websocket connection
# 2023-04-21 22:07:20,137: root: INFO: Risk Free Rate 4.95%
# 2023-04-21 22:07:20,327: alpaca_trade_api.stream: INFO: connected to: wss://api.alpaca.markets/stream/
# 2023-04-21 22:07:20,419: root: INFO: CustomETF : Executing the initialize lifecycle method
# 2023-04-21 22:07:20,693: root: INFO: CustomETF : Executing the on_trading_iteration lifecycle method
# 2023-04-21 22:07:20,945: root: INFO: CustomETF : Last price for BTC is 28,050.000000, and our weight is 0.32. Current portfolio value is 735.26141189482
# 2023-04-21 22:07:20,952: root: INFO: CustomETF : Currently own 0.00798 shares of BTC but need 0.008388008977053205, so the difference is 0.000408008977053205
# 2023-04-21 22:07:21,021: root: INFO: CustomETF : Executing the on_abrupt_closing event method
# 2023-04-21 22:07:21,034: root: INFO: Trading finished
# 2023-04-21 22:07:21,029: root: INFO: CustomETF : Last price for ETH is 1,907.170000, and our weight is 0.32. Current portfolio value is 735.26141189482
# 2023-04-21 22:07:21,043: root: INFO: CustomETF : Currently own 0.123665 shares of ETH but need 0.12336794926846709, so the difference is -0.00029705073153291
# 2023-04-21 22:07:21,116: root: INFO: CustomETF : Last price for LTC is 89.260000, and our weight is 0.32. Current portfolio value is 735.26141189482
# 2023-04-21 22:07:21,118: root: INFO: CustomETF : Currently own 2.6340125 shares of LTC but need 2.635936049813381, so the difference is 0.001923549813381
# 2023-04-21 22:07:21,197: root: INFO: market order of | 0.001 LTC/USD buy | with status error did not go through. The following error occured: cost basis must be >= minimal amount of order 1
